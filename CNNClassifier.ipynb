# %% [markdown]
# <a href="https://colab.research.google.com/github/icanardahan/GithubProjelerindeS-r-mTahmini/blob/main/CNNClassifier.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a772b777-9cd3-4e6b-ade0-775976b4cf66" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a772b777-9cd3-4e6b-ade0-775976b4cf66">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Release_Notes_v0_cleaned.csv to Release_Notes_v0_cleaned.csv

# %%
import pandas as pd
import numpy as np
import time

from keras import layers
from keras.models import Sequential
from keras.layers import Dense, Activation
from keras.preprocessing.text import Tokenizer, one_hot
from keras.preprocessing.sequence import pad_sequences

import sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix

# %%
data = pd.read_excel('Release_Notes_v0_cleaned.xlsx', sep = "," , names = ['Type', 'Note'])

# %%
# The maximum number of words to be used. (most frequent)
MAX_NB_WORDS = 500000
# Max number of words in each complaint.
MAX_SEQUENCE_LENGTH = 700
# This is fixed.
EMBEDDING_DIM = 100

X = pd.get_dummies(data['Note']).values
Y = pd.get_dummies(data['Type']).values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size = 0.10, random_state=42)
print(X_train.shape,y_train.shape)
print(X_test.shape,y_test.shape)
# Out:
# (711, 607) (711, 12)
# (79, 607) (79, 12)

# %%
embedding_dim = 50

model = Sequential()
model.add(layers.Embedding(MAX_NB_WORDS, embedding_dim, input_length=MAX_SEQUENCE_LENGTH))
model.add(layers.Conv1D(128, 5, activation='relu'))
model.add(layers.Dense(12, activation='relu'))
model.add(layers.GlobalMaxPooling1D())
model.add(layers.Dense(12, activation='sigmoid'))
model.compile(optimizer='adam',
              loss='binary_crossentropy',
              metrics=['accuracy'])
print(model.summary())

# Fit model
history = model.fit(X_train, y_train,
                    epochs=5,
                    verbose=False,
                    validation_data=(X_test, y_test),
                    batch_size=5)
loss, accuracy = model.evaluate(X_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(X_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# embedding_2 (Embedding)      (None, 700, 50)           25000000
# _________________________________________________________________
# conv1d_2 (Conv1D)            (None, 696, 128)          32128
# _________________________________________________________________
# dense_4 (Dense)              (None, 696, 12)           1548
# _________________________________________________________________
# global_max_pooling1d_2 (Glob (None, 12)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 12)                156
# ...
# Total params: 25,033,832
# Trainable params: 25,033,832
# Non-trainable params: 0
# _________________________________________________________________
# None
# ...

# %%
accr = model.evaluate(X_test,y_test)
print('Test set\n  Loss: {:0.3f}\n  Accuracy: {:0.3f}'.format(accr[0],accr[1]))
# Out:
# 3/3 [==============================] - 0s 6ms/step - loss: 0.1972 - accuracy: 0.4430
# Test set
#   Loss: 0.197
#   Accuracy: 0.443
